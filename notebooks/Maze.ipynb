# %% [markdown]
# # ACS2 in Maze
# This notebook presents how to integrate ACS2 algorithm with maze environment (using OpenAI Gym interface).
#
# Begin with attaching required dependencies. Because most of the work is by now done locally no PIP modules are used (just pure OS paths)

# %%
# General
from __future__ import unicode_literals

# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# To avoid Type3 fonts in generated pdf file
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# Logger
import logging
logging.basicConfig(level=logging.INFO)

# ALCS + Custom environments
import sys, os
sys.path.append(os.path.abspath('../'))

# Enable automatic module reload
# %load_ext autoreload
# %autoreload 2

# Load PyALCS module
from lcs.agents.acs2 import ACS2, Configuration, ClassifiersList

# Load environments
import gym
import gym_maze

# %% [markdown]
# ## Environment - Maze
# We are going to look at provided mazes. Their names starts with "_Maze..._" or "_Woods..._" so see what is possible to load:

# %%
# Custom function for obtaining available environments
filter_envs = lambda env: env.id.startswith("Maze") or env.id.startswith("Woods")

all_envs = [env for env in gym.envs.registry.all()]
maze_envs = [env for env in all_envs if filter_envs(env)]

for env in maze_envs:
    print("Maze ID: [{}], non-deterministic: [{}], trials: [{}]".format(
            env.id, env.nondeterministic, env.trials))
# Out:
# Maze ID: [MazeF1-v0], non-deterministic: [False], trials: [100]
# Maze ID: [MazeF2-v0], non-deterministic: [False], trials: [100]
# Maze ID: [MazeF3-v0], non-deterministic: [False], trials: [100]
# Maze ID: [MazeF4-v0], non-deterministic: [True], trials: [100]
# Maze ID: [Maze4-v0], non-deterministic: [False], trials: [100]
# Maze ID: [Maze5-v0], non-deterministic: [False], trials: [100]
# Maze ID: [Maze6-v0], non-deterministic: [True], trials: [100]
# Maze ID: [MazeT2-v0], non-deterministic: [False], trials: [100]
# Maze ID: [MazeT3-v0], non-deterministic: [False], trials: [100]
# Maze ID: [MazeT4-v0], non-deterministic: [True], trials: [100]
# Maze ID: [Woods1-v0], non-deterministic: [False], trials: [100]
# Maze ID: [Woods14-v0], non-deterministic: [False], trials: [100]

# %% [markdown]
# Let's see how it looks in action. First we are going to initialize new environment using `gym.make()` instruction from OpenAI Gym.

# %%
#MAZE = "Woods14-v0"
MAZE = "Maze5-v0"

# Initialize environment
maze = gym.make(MAZE)

# Reset it, by putting an agent into random position
situation = maze.reset()

# Render the state in ASCII
maze.render()
# Out:
# ■ ■ ■ ■ ■ ■ ■ ■ ■
# ■ □ □ □ □ □ □ $ ■
# ■ □ □ ■ □ ■ ■ □ ■
# ■ □ ■ □ □ □ □ □ ■
# ■ □ □ □ ■ ■ □ □ ■
# ■ A ■ □ ■ □ □ ■ ■
# ■ □ ■ □ □ ■ □ □ ■
# ■ □ □ □ □ □ ■ □ ■
# ■ ■ ■ ■ ■ ■ ■ ■ ■

# %% [markdown]
# The `reset()` function puts an agent into random position (on path inside maze) returning current perception.
#
# > The perception consists of 8 values representing N, NE, E, SE, S, SW, W, NW directions. It outputs 0 for the path, 1 for the wall and 9 for the reward.

# %%
# Show current agents perception
situation
# Out:
# ('0', '0', '1', '1', '0', '1', '1', '1')

# %% [markdown]
# We can interact with the environment by performing actions.
#
# > Agent can perform 8 actions - moving into different directions.
#
# To do so use `step(action)` function. It will return couple interesting information:
# - new state perception,
# - reward for executing move (ie. finding the reward)
# - is the trial finish,
# - debug data

# %%
ACTION = 0 # Move N

# Execute action
state, reward, done, _ = maze.step(ACTION)

# Show new state
print(f"New state: {state}, reward: {reward}, is done: {done}")

# Render the env one more time after executing step
maze.render()
# Out:
# New state: ('0', '1', '0', '1', '0', '1', '1', '1'), reward: 0, is done: False
#
# ■ ■ ■ ■ ■ ■ ■ ■ ■
# ■ □ □ □ □ □ □ $ ■
# ■ □ □ ■ □ ■ ■ □ ■
# ■ □ ■ □ □ □ □ □ ■
# ■ A □ □ ■ ■ □ □ ■
# ■ □ ■ □ ■ □ □ ■ ■
# ■ □ ■ □ □ ■ □ □ ■
# ■ □ □ □ □ □ ■ □ ■
# ■ ■ ■ ■ ■ ■ ■ ■ ■

# %% [markdown]
# ## Agent - ACS2
# First provide a helper method for calculating obtained knowledge

# %%
def _maze_knowledge(population, environment) -> float:
    transitions = environment.env.get_all_possible_transitions()

    # Take into consideration only reliable classifiers
    reliable_classifiers = [c for c in population if c.is_reliable()]

    # Count how many transitions are anticipated correctly
    nr_correct = 0

    # For all possible destinations from each path cell
    for start, action, end in transitions:

        p0 = environment.env.maze.perception(*start)
        p1 = environment.env.maze.perception(*end)

        if any([True for cl in reliable_classifiers
                if cl.predicts_successfully(p0, action, p1)]):
            nr_correct += 1

    return nr_correct / len(transitions) * 100.0

# %%
from lcs.metrics import population_metrics

def _maze_metrics(pop, env):
    metrics = {
        'knowledge': _maze_knowledge(pop, env)
    }

    # Add basic population metrics
    metrics.update(population_metrics(pop, env))
    
    return metrics

# %% [markdown]
# ### Exploration phase

# %%
CLASSIFIER_LENGTH=8
NUMBER_OF_POSSIBLE_ACTIONS=8

# Define agent's default configuration
cfg = Configuration(
    classifier_length=CLASSIFIER_LENGTH,
    number_of_possible_actions=NUMBER_OF_POSSIBLE_ACTIONS,
    biased_exploration=0.5,
    metrics_trial_frequency=1,
    user_metrics_collector_fcn=_maze_metrics)

# Define agent
agent = ACS2(cfg)

# %%
# %%time
population, metrics = agent.explore(maze, 100)
# Out:
# INFO:lcs.agents.Agent:{'trial': 0, 'steps_in_trial': 6, 'reward': 1000, 'knowledge': 0.0, 'population': 5, 'numerosity': 5, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 10, 'steps_in_trial': 2, 'reward': 1000, 'knowledge': 0.0, 'population': 139, 'numerosity': 139, 'reliable': 1}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 50, 'reward': 0, 'knowledge': 4.794520547945205, 'population': 259, 'numerosity': 259, 'reliable': 13}
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 50, 'reward': 0, 'knowledge': 6.8493150684931505, 'population': 324, 'numerosity': 324, 'reliable': 30}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 49, 'reward': 1000, 'knowledge': 10.95890410958904, 'population': 372, 'numerosity': 372, 'reliable': 41}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 14, 'reward': 1000, 'knowledge': 13.013698630136986, 'population': 383, 'numerosity': 383, 'reliable': 48}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 7, 'reward': 1000, 'knowledge': 19.17808219178082, 'population': 400, 'numerosity': 400, 'reliable': 66}
# INFO:lcs.agents.Agent:{'trial': 70, 'steps_in_trial': 39, 'reward': 1000, 'knowledge': 19.863013698630137, 'population': 397, 'numerosity': 397, 'reliable': 70}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 8, 'reward': 1000, 'knowledge': 22.602739726027394, 'population': 398, 'numerosity': 398, 'reliable': 80}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 15, 'reward': 1000, 'knowledge': 25.34246575342466, 'population': 402, 'numerosity': 402, 'reliable': 89}
# CPU times: user 7.31 s, sys: 61 ms, total: 7.37 s
# Wall time: 8.31 s

# %% [markdown]
# We can take a sneak peek into a created list of classifiers. Let's have a look at top 10:

# %%
population.sort(key=lambda cl: -cl.fitness)

for cl in population[:10]:
    print("{!r} \tq: {:.2f} \tr: {:.2f} \tir: {:.2f}".format(cl, cl.q, cl.r, cl.ir))
# Out:
# ##901### 2 ##110###         (empty)               q: 0.917 r: 806.3  ir: 806.3  f: 739.3  exp: 31  tga: 5     talp: 2895  tav: 85.8   num: 1 	q: 0.92 	r: 806.29 	ir: 806.29
# 9####010 0 1####101         (empty)               q: 0.913 r: 796.7  ir: 796.1  f: 727.1  exp: 31  tga: 99    talp: 2928  tav: 85.1   num: 1 	q: 0.91 	r: 796.73 	ir: 796.09
# 9#1##010 0 1####101         (empty)               q: 0.898 r: 796.7  ir: 796.1  f: 715.5  exp: 31  tga: 99    talp: 2928  tav: 85.2   num: 1 	q: 0.90 	r: 796.73 	ir: 796.09
# 1#0110## 2 ##90#1##         (empty)               q: 0.99  r: 409.5  ir: 0.0    f: 405.3  exp: 33  tga: 281   talp: 2925  tav: 75.7   num: 1 	q: 0.99 	r: 409.47 	ir: 0.00
# 1#01100# 2 ##90#1##         (empty)               q: 0.982 r: 409.5  ir: 0.0    f: 402.2  exp: 33  tga: 281   talp: 2925  tav: 74.9   num: 1 	q: 0.98 	r: 409.47 	ir: 0.00
# 11011001 2 ##90#1##         (empty)               q: 0.903 r: 409.4  ir: 0.0    f: 369.7  exp: 33  tga: 281   talp: 2925  tav: 74.5   num: 1 	q: 0.90 	r: 409.37 	ir: 0.00
# 1000#101 1 9111#010         (empty)               q: 0.887 r: 340.7  ir: 0.0    f: 302.3  exp: 26  tga: 136   talp: 2911  tav: 1.04e+02 num: 1 	q: 0.89 	r: 340.75 	ir: 0.00
# 00100#10 1 11011#01         (empty)               q: 0.997 r: 211.0  ir: 0.0    f: 210.4  exp: 38  tga: 1167  talp: 2924  tav: 41.9   num: 1 	q: 1.00 	r: 210.98 	ir: 0.00
# 00100010 1 11011#01         (empty)               q: 0.985 r: 210.7  ir: 0.0    f: 207.7  exp: 38  tga: 1167  talp: 2924  tav: 42.0   num: 1 	q: 0.99 	r: 210.72 	ir: 0.00
# 1####### 0 ########         (empty)               q: 0.996 r: 160.1  ir: 0.0    f: 159.5  exp: 84  tga: 30    talp: 2927  tav: 48.3   num: 1 	q: 1.00 	r: 160.15 	ir: 0.00

# %% [markdown]
# ### Exploitation

# %% [markdown]
# Now we can either reuse our previous agent or initialize it one more time passing the initial population of classifiers as *apriori* knowledge.

# %%
# Reinitialize agent using defined configuration and population
agent = ACS2(cfg, population)

# %%
# %%time
population, metrics = agent.exploit(maze, 1)
# Out:
# CPU times: user 39.6 ms, sys: 1.33 ms, total: 41 ms
# Wall time: 41.1 ms

# %%
metrics[-1]
# Out:
# {'trial': 0,
#  'steps_in_trial': 6,
#  'reward': 1000,
#  'knowledge': 26.71232876712329,
#  'population': 406,
#  'numerosity': 406,
#  'reliable': 92}

# %% [markdown]
# ## Experiments

# %%
def parse_metrics_to_df(explore_metrics, exploit_metrics):
    def extract_details(row):
        row['trial'] = row['trial']
        row['steps'] = row['steps_in_trial']
        row['numerosity'] = row['numerosity']
        row['reliable'] = row['reliable']
        row['knowledge'] = row['knowledge']
        return row
    
    # Load both metrics into data frame
    explore_df = pd.DataFrame(explore_metrics)
    exploit_df = pd.DataFrame(exploit_metrics)
    
    # Mark them with specific phase
    explore_df['phase'] = 'explore'
    exploit_df['phase'] = 'exploit'
    
    # Extract details
    explore_df = explore_df.apply(extract_details, axis=1)
    exploit_df = exploit_df.apply(extract_details, axis=1)
    
    # Adjuts exploit trial counter
    exploit_df['trial'] = exploit_df.apply(lambda r: r['trial']+len(explore_df), axis=1)
    
    # Concatenate both dataframes
    df = pd.concat([explore_df, exploit_df])
    df.set_index('trial', inplace=True)
    
    return df

# %% [markdown]
# For various mazes visualize
# - classifiers / reliable classifiers for steps
# - optimal policy
# - steps (exploration | exploitation)
# - knowledge
# - parameters setting

# %%
def find_best_classifier(population, situation, cfg):
    match_set = population.form_match_set(situation)
    anticipated_change_cls = [cl for cl in match_set if cl.does_anticipate_change()]
    
    if (len(anticipated_change_cls) > 0):
        return max(anticipated_change_cls, key=lambda cl: cl.fitness)
    
    return None

def build_fitness_matrix(env, population, cfg):
    original = env.env.maze.matrix
    fitness = original.copy()
    
    # Think about more 'functional' way of doing this
    for index, x in np.ndenumerate(original):
        # Path - best classfier fitness
        if x == 0:
            perception = env.env.maze.perception(index[1], index[0])
            best_cl = find_best_classifier(population, perception, cfg)
            if best_cl:
                fitness[index] = best_cl.fitness
            else:
                fitness[index] = -1
        
        # Wall - fitness = 0
        if x == 1:
            fitness[index] = 0
        
        # Reward - inf fitness
        if x == 9:
            fitness[index] = fitness.max () + 500
        
    return fitness
    
def build_action_matrix(env, population, cfg):
    ACTION_LOOKUP = { 
        0: u'↑', 1: u'↗', 2: u'→', 3: u'↘',
        4: u'↓', 5: u'↙', 6: u'←', 7: u'↖'
    }
    
    original = env.env.maze.matrix
    action = original.copy().astype(str)
    
    # Think about more 'functional' way of doing this
    for index, x in np.ndenumerate(original):
        # Path - best classfier fitness
        if x == 0:
            perception = env.env.maze.perception(index[1], index[0])
            best_cl = find_best_classifier(population, perception, cfg)
            if best_cl:
                action[index] = ACTION_LOOKUP[best_cl.action]
            else:
                action[index] = '?'
        
        # Wall - fitness = 0
        if x == 1:
            action[index] = '\#'
        
        # Reward - inf fitness
        if x == 9:
            action[index] = 'R'
        
    return action

# %% [markdown]
# ## Plotting functions and settings

# %%
# Plot constants
TITLE_TEXT_SIZE=24
AXIS_TEXT_SIZE=18
LEGEND_TEXT_SIZE=16

# %%
def plot_policy(env, agent, cfg, ax=None):
    if ax is None:
        ax = plt.gca()
    
    ax.set_aspect("equal")
    
    # Handy variables
    maze_countours = maze.env.maze.matrix
    max_x = env.env.maze.max_x
    max_y = env.env.maze.max_y
    
    fitness_matrix = build_fitness_matrix(env, agent.population, cfg)
    action_matrix = build_action_matrix(env, agent.population, cfg)
    
    # Render maze as image
    plt.imshow(fitness_matrix, interpolation='nearest', cmap='Reds', aspect='auto',
           extent=[0, max_x, max_y, 0])
    
    
    # Add labels to each cell
    for (y,x), val in np.ndenumerate(action_matrix):
        plt.text(x+0.4, y+0.5, "${}$".format(val))
    
    ax.set_title("Policy", fontsize=TITLE_TEXT_SIZE)
    ax.set_xlabel('x', fontsize=AXIS_TEXT_SIZE)
    ax.set_ylabel('y', fontsize=AXIS_TEXT_SIZE)

    ax.set_xlim(0, max_x)
    ax.set_ylim(max_y, 0)
    
    ax.set_xticks(range(0, max_x))
    ax.set_yticks(range(0, max_y))
    
    ax.grid(True)

# %%
def plot_knowledge(df, ax=None):
    if ax is None:
        ax = plt.gca()
    
    explore_df = df.query("phase == 'explore'")
    exploit_df = df.query("phase == 'exploit'")
        
    explore_df['knowledge'].plot(ax=ax, c='blue')
    exploit_df['knowledge'].plot(ax=ax, c='red')
    ax.axvline(x=len(explore_df), c='black', linestyle='dashed')
        
    ax.set_title("Achieved knowledge", fontsize=TITLE_TEXT_SIZE)
    ax.set_xlabel("Trial", fontsize=AXIS_TEXT_SIZE)
    ax.set_ylabel("Knowledge [%]", fontsize=AXIS_TEXT_SIZE)
    ax.set_ylim([0, 105])

# %%
def plot_steps(df, ax=None):
    if ax is None:
        ax = plt.gca()
    
    explore_df = df.query("phase == 'explore'")
    exploit_df = df.query("phase == 'exploit'")
    
    explore_df['steps'].plot(ax=ax, c='blue', linewidth=.5)
    exploit_df['steps'].plot(ax=ax, c='red', linewidth=0.5)
    ax.axvline(x=len(explore_df), c='black', linestyle='dashed')
    
    ax.set_title("Steps", fontsize=TITLE_TEXT_SIZE)
    ax.set_xlabel("Trial", fontsize=AXIS_TEXT_SIZE)
    ax.set_ylabel("Steps", fontsize=AXIS_TEXT_SIZE)

# %%
def plot_classifiers(df, ax=None):
    if ax is None:
        ax = plt.gca()
    
    explore_df = df.query("phase == 'explore'")
    exploit_df = df.query("phase == 'exploit'")
    
    df['numerosity'].plot(ax=ax, c='blue')
    df['reliable'].plot(ax=ax, c='red')    
    
    ax.axvline(x=len(explore_df), c='black', linestyle='dashed')
    
    ax.set_title("Classifiers", fontsize=TITLE_TEXT_SIZE)
    ax.set_xlabel("Trial", fontsize=AXIS_TEXT_SIZE)
    ax.set_ylabel("Classifiers", fontsize=AXIS_TEXT_SIZE)
    ax.legend(fontsize=LEGEND_TEXT_SIZE)

# %%
def plot_performance(agent, maze, metrics_df, cfg, env_name):
    plt.figure(figsize=(13, 10), dpi=100)
    plt.suptitle(f'ACS2 Performance in {env_name} environment', fontsize=32)
    
    ax1 = plt.subplot(221)
    plot_policy(maze, agent, cfg, ax1)
    
    ax2 = plt.subplot(222)
    plot_knowledge(metrics_df, ax2)
    
    ax3 = plt.subplot(223)
    plot_classifiers(metrics_df, ax3)
    
    ax4 = plt.subplot(224)
    plot_steps(metrics_df, ax4)
    
    plt.subplots_adjust(top=0.86, wspace=0.3, hspace=0.3)

# %% [markdown]
# ## Maze5

# %%
# %%time

# define environment
maze5 = gym.make('Maze5-v0')

# explore
agent_maze5 = ACS2(cfg)
population_maze5_explore, metrics_maze5_explore = agent_maze5.explore(maze5, 3000)
# Out:
# INFO:lcs.agents.Agent:{'trial': 0, 'steps_in_trial': 50, 'reward': 0, 'knowledge': 0.0, 'population': 27, 'numerosity': 27, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 10, 'reward': 1000, 'knowledge': 60.273972602739725, 'population': 486, 'numerosity': 486, 'reliable': 223}
# INFO:lcs.agents.Agent:{'trial': 600, 'steps_in_trial': 2, 'reward': 1000, 'knowledge': 84.93150684931507, 'population': 440, 'numerosity': 440, 'reliable': 316}
# INFO:lcs.agents.Agent:{'trial': 900, 'steps_in_trial': 5, 'reward': 1000, 'knowledge': 90.41095890410958, 'population': 438, 'numerosity': 438, 'reliable': 341}
# INFO:lcs.agents.Agent:{'trial': 1200, 'steps_in_trial': 17, 'reward': 1000, 'knowledge': 97.26027397260275, 'population': 418, 'numerosity': 418, 'reliable': 377}
# INFO:lcs.agents.Agent:{'trial': 1500, 'steps_in_trial': 4, 'reward': 1000, 'knowledge': 97.26027397260275, 'population': 423, 'numerosity': 423, 'reliable': 380}
# INFO:lcs.agents.Agent:{'trial': 1800, 'steps_in_trial': 16, 'reward': 1000, 'knowledge': 98.63013698630137, 'population': 417, 'numerosity': 417, 'reliable': 387}
# INFO:lcs.agents.Agent:{'trial': 2100, 'steps_in_trial': 2, 'reward': 1000, 'knowledge': 100.0, 'population': 415, 'numerosity': 415, 'reliable': 394}
# INFO:lcs.agents.Agent:{'trial': 2400, 'steps_in_trial': 11, 'reward': 1000, 'knowledge': 100.0, 'population': 410, 'numerosity': 410, 'reliable': 400}
# INFO:lcs.agents.Agent:{'trial': 2700, 'steps_in_trial': 2, 'reward': 1000, 'knowledge': 100.0, 'population': 407, 'numerosity': 407, 'reliable': 400}
# CPU times: user 5min 48s, sys: 2.51 s, total: 5min 50s
# Wall time: 6min 32s

# %%
# exploit
agent_maze5 = ACS2(cfg, population_maze5_explore)
_, metrics_maze5_exploit = agent_maze5.exploit(maze5, 400)
# Out:
# INFO:lcs.agents.Agent:{'trial': 0, 'steps_in_trial': 6, 'reward': 1000, 'knowledge': 100.0, 'population': 403, 'numerosity': 403, 'reliable': 400}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 7, 'reward': 1000, 'knowledge': 100.0, 'population': 403, 'numerosity': 403, 'reliable': 400}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 2, 'reward': 1000, 'knowledge': 100.0, 'population': 403, 'numerosity': 403, 'reliable': 400}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 2, 'reward': 1000, 'knowledge': 100.0, 'population': 403, 'numerosity': 403, 'reliable': 400}
# INFO:lcs.agents.Agent:{'trial': 160, 'steps_in_trial': 5, 'reward': 1000, 'knowledge': 100.0, 'population': 403, 'numerosity': 403, 'reliable': 400}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 6, 'reward': 1000, 'knowledge': 100.0, 'population': 403, 'numerosity': 403, 'reliable': 400}
# INFO:lcs.agents.Agent:{'trial': 240, 'steps_in_trial': 2, 'reward': 1000, 'knowledge': 100.0, 'population': 403, 'numerosity': 403, 'reliable': 400}
# INFO:lcs.agents.Agent:{'trial': 280, 'steps_in_trial': 3, 'reward': 1000, 'knowledge': 100.0, 'population': 403, 'numerosity': 403, 'reliable': 400}
# INFO:lcs.agents.Agent:{'trial': 320, 'steps_in_trial': 5, 'reward': 1000, 'knowledge': 100.0, 'population': 403, 'numerosity': 403, 'reliable': 400}
# INFO:lcs.agents.Agent:{'trial': 360, 'steps_in_trial': 2, 'reward': 1000, 'knowledge': 100.0, 'population': 403, 'numerosity': 403, 'reliable': 400}

# %%
maze5_metrics_df = parse_metrics_to_df(metrics_maze5_explore, metrics_maze5_exploit)

# %%
plot_performance(agent_maze5, maze5, maze5_metrics_df, cfg, 'Maze5')

# %% [markdown]
# ## Woods14

# %%
# %%time

# define environment
woods14 = gym.make('Woods14-v0')

# explore
agent_woods14 = ACS2(cfg)
population_woods14_explore, metrics_woods14_explore = agent_woods14.explore(woods14, 10_000)
# Out:
# INFO:lcs.agents.Agent:{'trial': 0, 'steps_in_trial': 50, 'reward': 0, 'knowledge': 0.0, 'population': 20, 'numerosity': 20, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 1000, 'steps_in_trial': 1, 'reward': 1000, 'knowledge': 100.0, 'population': 111, 'numerosity': 111, 'reliable': 111}
# INFO:lcs.agents.Agent:{'trial': 2000, 'steps_in_trial': 22, 'reward': 1000, 'knowledge': 100.0, 'population': 111, 'numerosity': 111, 'reliable': 111}
# INFO:lcs.agents.Agent:{'trial': 3000, 'steps_in_trial': 11, 'reward': 1000, 'knowledge': 100.0, 'population': 111, 'numerosity': 111, 'reliable': 111}
# INFO:lcs.agents.Agent:{'trial': 4000, 'steps_in_trial': 9, 'reward': 1000, 'knowledge': 100.0, 'population': 111, 'numerosity': 111, 'reliable': 111}
# INFO:lcs.agents.Agent:{'trial': 5000, 'steps_in_trial': 14, 'reward': 1000, 'knowledge': 100.0, 'population': 111, 'numerosity': 111, 'reliable': 111}
# INFO:lcs.agents.Agent:{'trial': 6000, 'steps_in_trial': 10, 'reward': 1000, 'knowledge': 100.0, 'population': 111, 'numerosity': 111, 'reliable': 111}
# INFO:lcs.agents.Agent:{'trial': 7000, 'steps_in_trial': 18, 'reward': 1000, 'knowledge': 100.0, 'population': 111, 'numerosity': 111, 'reliable': 111}
# INFO:lcs.agents.Agent:{'trial': 8000, 'steps_in_trial': 17, 'reward': 1000, 'knowledge': 100.0, 'population': 111, 'numerosity': 111, 'reliable': 111}
# INFO:lcs.agents.Agent:{'trial': 9000, 'steps_in_trial': 10, 'reward': 1000, 'knowledge': 100.0, 'population': 111, 'numerosity': 111, 'reliable': 111}
# CPU times: user 4min 36s, sys: 2.07 s, total: 4min 38s
# Wall time: 5min 17s

# %%
# exploit
agent_woods14 = ACS2(cfg, population_woods14_explore)
_, metrics_woods14_exploit = agent_woods14.exploit(woods14, 200)
# Out:
# INFO:lcs.agents.Agent:{'trial': 0, 'steps_in_trial': 2, 'reward': 1000, 'knowledge': 100.0, 'population': 111, 'numerosity': 111, 'reliable': 111}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 18, 'reward': 1000, 'knowledge': 100.0, 'population': 111, 'numerosity': 111, 'reliable': 111}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 15, 'reward': 1000, 'knowledge': 100.0, 'population': 111, 'numerosity': 111, 'reliable': 111}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 18, 'reward': 1000, 'knowledge': 100.0, 'population': 111, 'numerosity': 111, 'reliable': 111}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 3, 'reward': 1000, 'knowledge': 100.0, 'population': 111, 'numerosity': 111, 'reliable': 111}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 9, 'reward': 1000, 'knowledge': 100.0, 'population': 111, 'numerosity': 111, 'reliable': 111}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 12, 'reward': 1000, 'knowledge': 100.0, 'population': 111, 'numerosity': 111, 'reliable': 111}
# INFO:lcs.agents.Agent:{'trial': 140, 'steps_in_trial': 16, 'reward': 1000, 'knowledge': 100.0, 'population': 111, 'numerosity': 111, 'reliable': 111}
# INFO:lcs.agents.Agent:{'trial': 160, 'steps_in_trial': 11, 'reward': 1000, 'knowledge': 100.0, 'population': 111, 'numerosity': 111, 'reliable': 111}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 3, 'reward': 1000, 'knowledge': 100.0, 'population': 111, 'numerosity': 111, 'reliable': 111}

# %%
woods14_metrics_df = parse_metrics_to_df(metrics_woods14_explore, metrics_woods14_exploit)

# %%
plot_performance(agent_woods14, woods14, woods14_metrics_df, cfg, 'Woods14')
